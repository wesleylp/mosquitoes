# %% [markdown]
# # Video Handling

# %%
# the notebook will reload external python modules;
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.insert(0, '../codes')

import matplotlib.pyplot as plt

import video_handling
import cv2
# Out:
# /home/wesley.passos/miniconda3/envs/mosquitoes/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
#make matplotlib figures appear inline in the notebook
#rather than in a new window.
# %matplotlib inline
#sns.set()
# set default size of plots
plt.rcParams['figure.figsize'] = (12.0, 10.0) 
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20

# %% [markdown]
# ## Choosing video to test

# %%
video_path = '../data/DJI4_cam/'
video_name = 'DJI_0001.MOV'
video = os.path.join(video_path, video_name)

# %% [markdown]
# ## Creating video object

# %%
vid = video_handling.videoObj(videopath=video)

# %% [markdown]
# ### We can access specific video information:

# %%
total_frames = vid.videoInfo.getNumberOfFrames()
frame_rate = vid.videoInfo.getFrameRate()
print('This video has {} frames.'.format(total_frames))
print('Frame rate: {}.'.format(frame_rate))
# Out:
# This video has 686 frames.
# Frame rate: 48000/1001.

# %% [markdown]
# ### We can print all available video information

# %%
vid.videoInfo.printAllInformation()
# Out:
# *************************************
# ************* video info ************
#
# File path: ../data/DJI4_cam/DJI_0001.MOV
# File name: DJI_0001.MOV
# File extension: mov,mp4,m4a,3gp,3g2,mj2 (QuickTime / MOV)
# Created on: 2018-07-19T11:26:37.000000Z
# File size: 180724884
# Codec: h264 (H.264 / AVC / MPEG-4 AVC / MPEG-4 part 10)
# Width: 4096
# Height: 2160
# Width x Height: [4096, 2160]
# Sample aspect ratio: None
# Display aspect ratio: None
# Pixel format: yuv420p
# Frame rate: 48000/1001
# Duration ts: 686686
# Duration: 14.305958
# Bit rate: 100938064
# Number of frames: 686
#
# *************************************

# %% [markdown]
# ## Getting a certain video frame

# %%
#using method get_frame to capture a certain frame number
ret, frame, frame_size = vid.get_frame(frame_req=20)

# %%
#displaying frame
plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
print('image size: ', frame_size)
# Out:
# image size:  (2160, 4096, 3)

# %% [markdown]
# ## Extracting and saving video frames

# %%
vid.save_frames(first_frame=1, last_frame=15, every=2, filename_prefix='my_frame_')
# Out:
# ...
# Error saving file saved: ../data/DJI4_cam/DJI_0001_frames/my_frame_0001.jpg
# Error saving file saved: ../data/DJI4_cam/DJI_0001_frames/my_frame_0003.jpg
# Error saving file saved: ../data/DJI4_cam/DJI_0001_frames/my_frame_0005.jpg
# Error saving file saved: ../data/DJI4_cam/DJI_0001_frames/my_frame_0007.jpg
# Error saving file saved: ../data/DJI4_cam/DJI_0001_frames/my_frame_0009.jpg
# Error saving file saved: ../data/DJI4_cam/DJI_0001_frames/my_frame_0011.jpg
# Error saving file saved: ../data/DJI4_cam/DJI_0001_frames/my_frame_0013.jpg
