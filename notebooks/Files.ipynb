# %% [markdown]
# # Looking for video files using `Directory` Class

# %%
# the notebook will reload external python modules;
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../codes/')
from utils.files_utils import Directory
from video_handling import videoObj
# Out:
# /home/wesley.passos/miniconda3/envs/mosquitoes/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
vid_dir = '../data/dataset/2018-09-19/'

# %%
files = Directory.get_files(root_dir=vid_dir, ext=('.mov','.mp4'), recursive=True)
files
# Out:
# ['../data/dataset/2018-09-19/seq001/calibration/DJI_0017.MOV',
#  '../data/dataset/2018-09-19/seq001/missions/DJI_0018.MOV',
#  '../data/dataset/2018-09-19/seq001/missions/DJI_0019.MOV',
#  '../data/dataset/2018-09-19/seq001/missions/rectfied_DJI_0018.MOV',
#  '../data/dataset/2018-09-19/seq001/missions/rectfied_DJI_0019.MOV',
#  '../data/dataset/2018-09-19/seq002/calibration/DJI_0020.MOV',
#  '../data/dataset/2018-09-19/seq002/missions/DJI_0021.MOV',
#  '../data/dataset/2018-09-19/seq002/missions/rectfied_DJI_0021.MOV']

# %%
for file in files:
    video = videoObj(file)
    video.videoInfo.printAllInformation()
# Out:
# *************************************
# ************* video info ************
#
# File path: ../data/dataset/2018-09-19/seq001/calibration/DJI_0017.MOV
# File name: DJI_0017.MOV
# File extension: mov,mp4,m4a,3gp,3g2,mj2 (QuickTime / MOV)
# Created on: 2018-09-19T14:01:33.000000Z
# File size: 247272567
# Codec: h264 (H.264 / AVC / MPEG-4 AVC / MPEG-4 part 10)
# Width: 3840
# Height: 2160
# Width x Height: [3840, 2160]
# Sample aspect ratio: None
# Display aspect ratio: None
# Pixel format: yuv420p
# Frame rate: 48000/1001
# Duration ts: 940940
# Duration: 19.602917
# Bit rate: 100836465
# Number of frames: 940
#
# *************************************
#
# *************************************
# ************* video info ************
#
# File path: ../data/dataset/2018-09-19/seq001/missions/DJI_0018.MOV
# File name: DJI_0018.MOV
# File extension: mov,mp4,m4a,3gp,3g2,mj2 (QuickTime / MOV)
# Created on: 2018-09-19T14:02:45.000000Z
# File size: 298014152
# ...
