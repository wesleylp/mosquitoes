# %%
import torch
import matplotlib.pyplot as plt

# %%
feature_map = torch.rand(7, 8).cpu()
print(feature_map)
print(feature_map.shape)
# feature_map = feature_map.squeeze()
plt.imshow(feature_map.numpy())
plt.show()
# Out:
# tensor([[0.4241, 0.7236, 0.8447, 0.3972, 0.1899, 0.9530, 0.3404, 0.4343],
#         [0.6866, 0.1592, 0.4473, 0.8281, 0.0565, 0.6191, 0.0572, 0.8327],
#         [0.8167, 0.5700, 0.6183, 0.8114, 0.3298, 0.1180, 0.3989, 0.7793],
#         [0.5931, 0.5375, 0.9445, 0.2265, 0.9833, 0.0904, 0.5577, 0.6987],
#         [0.5535, 0.9848, 0.6202, 0.6956, 0.9760, 0.2473, 0.1631, 0.6186],
#         [0.4474, 0.2941, 0.9532, 0.5705, 0.1190, 0.1209, 0.7126, 0.5428],
#         [0.1445, 0.9588, 0.3692, 0.1737, 0.0694, 0.0351, 0.8401, 0.4613]])
# torch.Size([7, 8])

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

def plot_feat_map(cm, cmap=plt.cm.Blues):
    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap) 
    plt.axis('off')
#     plt.colorbar()

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    
# def plot_bb(x1, y1, x2, y2, colors='r'):
plt.hlines(0-1/2, 0-1/2,3-1/2, colors='r')


np.set_printoptions(precision=2)

# Plot feature map
plt.figure()
plot_feat_map(feature_map, )
plot_bb(0,0,3,3)
plt.show()
# Out:
# tensor([[0.4241, 0.7236, 0.8447, 0.3972, 0.1899, 0.9530, 0.3404, 0.4343],
#         [0.6866, 0.1592, 0.4473, 0.8281, 0.0565, 0.6191, 0.0572, 0.8327],
#         [0.8167, 0.5700, 0.6183, 0.8114, 0.3298, 0.1180, 0.3989, 0.7793],
#         [0.5931, 0.5375, 0.9445, 0.2265, 0.9833, 0.0904, 0.5577, 0.6987],
#         [0.5535, 0.9848, 0.6202, 0.6956, 0.9760, 0.2473, 0.1631, 0.6186],
#         [0.4474, 0.2941, 0.9532, 0.5705, 0.1190, 0.1209, 0.7126, 0.5428],
#         [0.1445, 0.9588, 0.3692, 0.1737, 0.0694, 0.0351, 0.8401, 0.4613]])
